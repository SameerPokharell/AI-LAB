# %%
x=int(input("Enter the digit"))
y=x
print(f"The fibo series can be as {x} {y}")
z=int(0)
i=0
for i in range(10):
    z=x+y
    print(z)
    x=y
    y=z
# Out:
# Enter the digit2
# The fibo series can be as 2 2
# 4
# 6
# 10
# 16
# 26
# 42
# 68
# 110
# 178
# 288
